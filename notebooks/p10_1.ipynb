# %%
import pandas as pd
import numpy as np

# %%
wine = pd.read_csv("wine.csv")

# %%
wine
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 0       14.23         1.71  2.43                  15.6         127
# 1       13.20         1.78  2.14                  11.2         100
# 2       13.16         2.36  2.67                  18.6         101
# 3       14.37         1.95  2.50                  16.8         113
# 4       13.24         2.59  2.87                  21.0         118
# ..        ...          ...   ...                   ...         ...
# 173     13.71         5.65  2.45                  20.5          95
# 174     13.40         3.91  2.48                  23.0         102
# 175     13.27         4.28  2.26                  20.0         120
# 176     13.17         2.59  2.37                  20.0         120
# 177     14.13         4.10  2.74                  24.5          96
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 0              2.80         3.06                   0.28              2.29
# ...

# %%
wine.drop([0, 3, 6, 8, 10, 12, 13])
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 1       13.20         1.78  2.14                  11.2         100
# 2       13.16         2.36  2.67                  18.6         101
# 4       13.24         2.59  2.87                  21.0         118
# 5       14.20         1.76  2.45                  15.2         112
# 7       14.06         2.15  2.61                  17.6         121
# ..        ...          ...   ...                   ...         ...
# 173     13.71         5.65  2.45                  20.5          95
# 174     13.40         3.91  2.48                  23.0         102
# 175     13.27         4.28  2.26                  20.0         120
# 176     13.17         2.59  2.37                  20.0         120
# 177     14.13         4.10  2.74                  24.5          96
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 1              2.65         2.76                   0.26              1.28
# ...

# %%
print(wine.columns)
# Out:
# Index([' Alcohol', ' Malic acid', ' Ash', ' Alcalinity of ash  ', ' Magnesium',
#        ' Total phenols', ' Flavanoids', ' Nonflavanoid phenols',
#        ' Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline       ', 'Class'],
#       dtype='object')

# %%
wine.loc[:2, ' Alcohol'] = np.nan
wine.head()
# Out:
#     Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 0       NaN         1.71  2.43                  15.6         127
# 1       NaN         1.78  2.14                  11.2         100
# 2       NaN         2.36  2.67                  18.6         101
# 3     14.37         1.95  2.50                  16.8         113
# 4     13.24         2.59  2.87                  21.0         118
#
#     Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 0            2.80         3.06                   0.28              2.29
# 1            2.65         2.76                   0.26              1.28
# 2            2.80         3.24                   0.30              2.81
# 3            3.85         3.49                   0.24              2.18
# 4            2.80         2.69                   0.39              1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline         Class
# ...

# %%
wine.loc[2:3, ' Magnesium'] = np.nan
wine.head()
# Out:
#     Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 0       NaN         1.71  2.43                  15.6       127.0
# 1       NaN         1.78  2.14                  11.2       100.0
# 2       NaN         2.36  2.67                  18.6         NaN
# 3     14.37         1.95  2.50                  16.8         NaN
# 4     13.24         2.59  2.87                  21.0       118.0
#
#     Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 0            2.80         3.06                   0.28              2.29
# 1            2.65         2.76                   0.26              1.28
# 2            2.80         3.24                   0.30              2.81
# 3            3.85         3.49                   0.24              2.18
# 4            2.80         2.69                   0.39              1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline         Class
# ...

# %%
wine = wine.fillna({' Alcohol': 10, ' Magnesium': 100})

# %%
wine
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 0       10.00         1.71  2.43                  15.6       127.0
# 1       10.00         1.78  2.14                  11.2       100.0
# 2       10.00         2.36  2.67                  18.6       100.0
# 3       14.37         1.95  2.50                  16.8       100.0
# 4       13.24         2.59  2.87                  21.0       118.0
# ..        ...          ...   ...                   ...         ...
# 173     13.71         5.65  2.45                  20.5        95.0
# 174     13.40         3.91  2.48                  23.0       102.0
# 175     13.27         4.28  2.26                  20.0       120.0
# 176     13.17         2.59  2.37                  20.0       120.0
# 177     14.13         4.10  2.74                  24.5        96.0
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 0              2.80         3.06                   0.28              2.29
# ...

# %%
wine.isna().sum()
# Out:
#  Alcohol                        0
#  Malic acid                     0
#  Ash                            0
#  Alcalinity of ash              0
#  Magnesium                      0
#  Total phenols                  0
#  Flavanoids                     0
#  Nonflavanoid phenols           0
#  Proanthocyanins                0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# Class                           0
# dtype: int64

# %%
random_rows = wine.sample(n=10, random_state=None)

display(random_rows)
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 123     13.05         5.80  2.13                  21.5        86.0
# 15      13.63         1.81  2.70                  17.2       112.0
# 132     12.81         2.31  2.40                  24.0        98.0
# 24      13.50         1.81  2.61                  20.0        96.0
# 109     11.61         1.35  2.70                  20.0        94.0
# 39      14.22         3.99  2.51                  13.2       128.0
# 67      12.37         1.17  1.92                  19.6        78.0
# 113     11.41         0.74  2.50                  21.0        88.0
# 41      13.41         3.84  2.12                  18.8        90.0
# 25      13.05         2.05  3.22                  25.0       124.0
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 123            2.62         2.65                   0.30              2.01
# 15             2.85         2.91                   0.30              1.46
# ...

# %%
wine.isna().sum().sum()
# Out:
# 0

# %%
wine = wine.dropna()

# %%
wine
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 0       10.00         1.71  2.43                  15.6       127.0
# 1       10.00         1.78  2.14                  11.2       100.0
# 2       10.00         2.36  2.67                  18.6       100.0
# 3       14.37         1.95  2.50                  16.8       100.0
# 4       13.24         2.59  2.87                  21.0       118.0
# ..        ...          ...   ...                   ...         ...
# 173     13.71         5.65  2.45                  20.5        95.0
# 174     13.40         3.91  2.48                  23.0       102.0
# 175     13.27         4.28  2.26                  20.0       120.0
# 176     13.17         2.59  2.37                  20.0       120.0
# 177     14.13         4.10  2.74                  24.5        96.0
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 0              2.80         3.06                   0.28              2.29
# ...

# %%
display(wine[' Alcohol'].dropna())
# Out:
# 0      10.00
# 1      10.00
# 2      10.00
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name:  Alcohol, Length: 178, dtype: float64

# %%
wine = wine.drop(index=wine.index[:4])

# %%
wine
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 4       13.24         2.59  2.87                  21.0       118.0
# 5       14.20         1.76  2.45                  15.2       112.0
# 6       14.39         1.87  2.45                  14.6        96.0
# 7       14.06         2.15  2.61                  17.6       121.0
# 8       14.83         1.64  2.17                  14.0        97.0
# ..        ...          ...   ...                   ...         ...
# 173     13.71         5.65  2.45                  20.5        95.0
# 174     13.40         3.91  2.48                  23.0       102.0
# 175     13.27         4.28  2.26                  20.0       120.0
# 176     13.17         2.59  2.37                  20.0       120.0
# 177     14.13         4.10  2.74                  24.5        96.0
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 4              2.80         2.69                   0.39              1.82
# ...

# %%
wine = wine.reset_index(drop=True)

# %%
wine
# Out:
#       Alcohol   Malic acid   Ash   Alcalinity of ash     Magnesium  \
# 0       13.24         2.59  2.87                  21.0       118.0
# 1       14.20         1.76  2.45                  15.2       112.0
# 2       14.39         1.87  2.45                  14.6        96.0
# 3       14.06         2.15  2.61                  17.6       121.0
# 4       14.83         1.64  2.17                  14.0        97.0
# ..        ...          ...   ...                   ...         ...
# 169     13.71         5.65  2.45                  20.5        95.0
# 170     13.40         3.91  2.48                  23.0       102.0
# 171     13.27         4.28  2.26                  20.0       120.0
# 172     13.17         2.59  2.37                  20.0       120.0
# 173     14.13         4.10  2.74                  24.5        96.0
#
#       Total phenols   Flavanoids   Nonflavanoid phenols   Proanthocyanins  \
# 0              2.80         2.69                   0.39              1.82
# ...
