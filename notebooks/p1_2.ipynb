# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('automation_data_by_state.csv', encoding='latin1')

# %%
df
# Out:
#          SOC                                 Occupation  Probability  Alabama  \
# 0    11-1011                           Chief Executives        0.015     1030
# 1    11-1021            General and Operations Managers        0.160    26930
# 2    11-2011        Advertising and Promotions Managers        0.039       50
# 3    11-2021                         Marketing Managers        0.014      530
# 4    11-2022                             Sales Managers        0.013     2510
# ..       ...                                        ...          ...      ...
# 697  53-7072    Pump Operators; Except Wellhead Pumpers        0.900        0
# 698  53-7073                           Wellhead Pumpers        0.840        0
# 699  53-7081  Refuse and Recyclable Material Collectors        0.930     2070
# 700  53-7111                 Mine Shuttle Car Operators        0.370       50
# 701  53-7121          Tank Car; Truck; and Ship Loaders        0.720      600
#
# ...

# %%
df.head(25)
# Out:
#         SOC                                         Occupation  Probability  \
# 0   11-1011                                   Chief Executives       0.0150
# 1   11-1021                    General and Operations Managers       0.1600
# 2   11-2011                Advertising and Promotions Managers       0.0390
# 3   11-2021                                 Marketing Managers       0.0140
# 4   11-2022                                     Sales Managers       0.0130
# 5   11-2031          Public Relations and Fundraising Managers       0.0150
# 6   11-3011                   Administrative Services Managers       0.7300
# 7   11-3021          Computer and Information Systems Managers       0.0350
# 8   11-3031                                 Financial Managers       0.0690
# 9   11-3051                     Industrial Production Managers       0.0300
# 10  11-3061                                Purchasing Managers       0.0300
# ...

# %%
df.tail(10)
# Out:
#          SOC                                         Occupation  Probability  \
# 692  53-7061                 Cleaners of Vehicles and Equipment         0.37
# 693  53-7062  Laborers and Freight; Stock; and Material Move...         0.85
# 694  53-7063                     Machine Feeders and Offbearers         0.93
# 695  53-7064                        Packers and Packagers; Hand         0.38
# 696  53-7071   Gas Compressor and Gas Pumping Station Operators         0.91
# 697  53-7072            Pump Operators; Except Wellhead Pumpers         0.90
# 698  53-7073                                   Wellhead Pumpers         0.84
# 699  53-7081          Refuse and Recyclable Material Collectors         0.93
# 700  53-7111                         Mine Shuttle Car Operators         0.37
# 701  53-7121                  Tank Car; Truck; and Ship Loaders         0.72
#
#      Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# ...

# %%
print(len(df))
# Out:
# 702

# %%
df.shape[1]
# Out:
# 54

# %%
df.index
# Out:
# RangeIndex(start=0, stop=702, step=1)

# %%
print(df.columns)
# Out:
# Index(['SOC', 'Occupation', 'Probability', 'Alabama', 'Alaska', 'Arizona',
#        'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
print(df.columns.dtype)
# Out:
# object

# %%
print(df['Occupation'])
# Out:
# 0                               Chief Executives
# 1                General and Operations Managers
# 2            Advertising and Promotions Managers
# 3                             Marketing Managers
# 4                                 Sales Managers
#                          ...
# 697      Pump Operators; Except Wellhead Pumpers
# 698                             Wellhead Pumpers
# 699    Refuse and Recyclable Material Collectors
# 700                   Mine Shuttle Car Operators
# 701            Tank Car; Truck; and Ship Loaders
# Name: Occupation, Length: 702, dtype: object

# %%
print(df['Occupation'].nunique())
# Out:
# 702

# %%
most_common_Weight = df['Occupation'].value_counts().idxmax()
count = df['Occupation'].value_counts().max()

print(f"The most frequent Weight(Pounds) is '{most_common_Weight}' with {count} users.")
# Out:
# The most frequent Weight(Pounds) is 'Chief Executives' with 1 users.

# %%
df.describe()
# Out:
#        Probability       Alabama        Alaska       Arizona      Arkansas  \
# count   702.000000    702.000000    702.000000    702.000000    702.000000
# mean      0.535550   2453.019943    405.868946   3354.757835   1524.757835
# std       0.368149   6290.975897    967.683396   8341.431586   3868.163503
# min       0.002800      0.000000      0.000000      0.000000      0.000000
# 25%       0.110000    112.500000      0.000000    140.000000     60.000000
# 50%       0.640000    550.000000     80.000000    695.000000    320.000000
# 75%       0.890000   2167.500000    370.000000   2817.500000   1287.500000
# max       0.990000  72610.000000  10470.000000  90030.000000  37840.000000
#
#          California      Colorado   Connecticut      Delaware  \
# count     702.00000    702.000000    702.000000    702.000000
# mean    20175.34188   3151.253561   2101.709402    528.589744
# std     45474.24833   7619.361786   4952.798565   1383.173852
# ...

# %%
df.describe(include='all')
# Out:
#             SOC        Occupation  Probability       Alabama        Alaska  \
# count       702               702   702.000000    702.000000    702.000000
# unique      702               702          NaN           NaN           NaN
# top     11-1011  Chief Executives          NaN           NaN           NaN
# freq          1                 1          NaN           NaN           NaN
# mean        NaN               NaN     0.535550   2453.019943    405.868946
# std         NaN               NaN     0.368149   6290.975897    967.683396
# min         NaN               NaN     0.002800      0.000000      0.000000
# 25%         NaN               NaN     0.110000    112.500000      0.000000
# 50%         NaN               NaN     0.640000    550.000000     80.000000
# 75%         NaN               NaN     0.890000   2167.500000    370.000000
# max         NaN               NaN     0.990000  72610.000000  10470.000000
#
# ...

# %%
print(df['Occupation'].describe())
# Out:
# count                  702
# unique                 702
# top       Chief Executives
# freq                     1
# Name: Occupation, dtype: object

# %%
print(df['Probability'].mean())
# Out:
# 0.5355498575498576

# %%
Probability_counts = df['Probability'].value_counts()
least_common_Probability = Probability_counts.idxmin()
least_common_count = Probability_counts.min()

print(f"The least frequent Probability is {least_common_Probability} and it appears {least_common_count} time(s).")
# Out:
# The least frequent Probability is 0.048 and it appears 1 time(s).
